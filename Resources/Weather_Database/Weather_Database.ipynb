# %%
#imports
import random as rn
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests
#out of context this sound kinda funny.
import time
from datetime import datetime
import os
import warnings
warnings.filterwarnings("ignore")

# %%
#step 3 make a set of 2000 random longitudes and Latitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
coords = list(lat_lngs)

# %%
#step 4 nearest city using citipy
cities = []
for coordinate in coords:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=022be10ce50c53dc255fb651599428ad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=022be10ce50c53dc255fb651599428ad&q=Boston

# %%
set_count = 1
city_data = []
record_count = 1
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        print("End of set {set_count}. Nap time!")
        time.sleep(60)
    url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
    city_url = url + "&q=" + city.replace(" ", "+")
    #print(city_url)
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    #step 5 calling
    city_weather = requests.get(city_url).json()
    #step 6 retrieving the data
    try:
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

#If an error is experienced, skip the city.
    except:
        print(f"{city} not found. Skipping...")
        pass
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | guerrero negro
# Processing Record 2 of Set 1 | vostok
# Processing Record 3 of Set 1 | bubaque
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | belushya guba
# belushya guba not found. Skipping...
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | beyneu
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | katsiveli
# katsiveli not found. Skipping...
# Processing Record 12 of Set 1 | hit
# Processing Record 13 of Set 1 | rusera
# Processing Record 14 of Set 1 | ruzomberok
# Processing Record 15 of Set 1 | los llanos de aridane
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | shubarshi
# Processing Record 19 of Set 1 | honiara
# Processing Record 20 of Set 1 | tomari
# ...

# %%
#step 7 add to data frame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Guerrero Negro      MX  27.9769 -114.0611     54.10        35           0
# 1          Vostok      RU  46.4856  135.8833    -12.28       100         100
# 2         Bubaque      GW  11.2833  -15.8333     79.43        56           0
# 3        Hermanus      ZA -34.4187   19.2345     76.89        53           7
# 4          Barrow      US  71.2906 -156.7887    -29.18        68           0
# 5      Nikolskoye      RU  59.7035   30.7861     19.29        96          82
# 6          Kodiak      US  57.7900 -152.4072     33.31        80           0
# 7          Beyneu      KZ  45.3167   55.2000     40.42        73         100
# 8           Bluff      NZ -46.6000  168.3333     48.79        66          66
# 9             Hit      IQ  33.6416   42.8251     56.10        56          42
#
#    Wind Speed Current Description
# 0        0.72           clear sky
# 1        3.51     overcast clouds
# ...

# %%
#step 8 save it into a .csv file
output_data_file  = os.path.join("..", "Weather_Database", "WeatherPy_Database.csv")
city_data_df.to_csv(output_data_file, index_label="City_ID")
